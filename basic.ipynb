# %%
pip install mat4py
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from mat4py import loadmat
import numpy as np
import matplotlib.pyplot as plt

# %%
bp_imag = loadmat('/Users/jessraissouni/github/motorImagery/sourcedata/imagery_basic/data/bp_im_t_h.mat')
bp_overt = loadmat('/Users/jessraissouni/github/motorImagery/sourcedata/imagery_basic/data/bp_mot_t_h.mat')

fp_imag = loadmat('/Users/jessraissouni/github/motorImagery/sourcedata/imagery_basic/data/fp_im_t_h.mat')
fp_overt = loadmat('/Users/jessraissouni/github/motorImagery/sourcedata/imagery_basic/data/fp_mot_t_h.mat')

hh_imag = loadmat('/Users/jessraissouni/github/motorImagery/sourcedata/imagery_basic/data/hh_im_t_h.mat')
hh_overt = loadmat('/Users/jessraissouni/github/motorImagery/sourcedata/imagery_basic/data/hh_mot_t_h.mat')

jc_imag = loadmat('/Users/jessraissouni/github/motorImagery/sourcedata/imagery_basic/data/jc_im_t_h.mat')
jc_overt = loadmat('/Users/jessraissouni/github/motorImagery/sourcedata/imagery_basic/data/jc_mot_t_h.mat')

jm_imag = loadmat('/Users/jessraissouni/github/motorImagery/sourcedata/imagery_basic/data/jm_im_t_h.mat')
jm_overt = loadmat('/Users/jessraissouni/github/motorImagery/sourcedata/imagery_basic/data/jm_mot_t_h.mat')

rh_imag = loadmat('/Users/jessraissouni/github/motorImagery/sourcedata/imagery_basic/data/rh_im_t_h.mat')
rh_overt = loadmat('/Users/jessraissouni/github/motorImagery/sourcedata/imagery_basic/data/rh_mot_t_h.mat')

rr_imag = loadmat('/Users/jessraissouni/github/motorImagery/sourcedata/imagery_basic/data/rr_im_t_h.mat')
rr_overt = loadmat('/Users/jessraissouni/github/motorImagery/sourcedata/imagery_basic/data/rr_mot_t_h.mat')

# %%
type(bp_imag)
# Out:
# dict

# %%
bp_imag.keys()
# Out:
# dict_keys(['data', 'stim'])

# %%
type(bp_imag['stim'])
# Out:
# list

# %%
len(bp_imag['stim'])
# Out:
# 376600

# %%
np.unique(bp_imag['stim'])
# Out:
# array([ 0, 11, 12])

# %%
bp_imag['data'][10000:10100]
# Out:
# [[2890,
#   1904,
#   2224,
#   3026,
#   2160,
#   1332,
#   -563,
#   -817,
#   1532,
#   294,
#   2346,
#   1273,
#   1642,
#   -1892,
#   1204,
#   3614,
#   1654,
#   -283,
#   3593,
#   730,
#   3588,
#   1733,
#   700,
#   3212,
#   -771,
#   127,
#   331,
#   718,
#   2379,
#   2619,
#   1694,
#   4299,
#   2960,
#   843,
#   1557,
#   2617,
#   2351,
#   -359,
#   -903,
#   1389,
#   940,
#   1222,
#   2065,
#   2483,
#   -323,
#   2807],
#  [2745,
#   1829,
#   2155,
#   2931,
#   2030,
#   1262,
#   -520,
#   -826,
#   1346,
#   248,
#   2195,
#   1342,
#   1597,
#   -1883,
#   1145,
#   3478,
#   1666,
#   -349,
#   3488,
#   743,
#   3591,
#   1559,
#   675,
#   3110,
#   -754,
#   132,
#   262,
#   556,
#   2338,
#   2435,
#   1523,
#   4209,
#   2987,
#   823,
#   1371,
#   2628,
#   2205,
#   -923,
#   -1347,
#   1372,
#   742,
#   998,
#   1961,
#   2322,
#   -722,
#   2491],
#  [2535,
#   1648,
#   1998,
#   2783,
#   1829,
#   1074,
#   -546,
#   -955,
#   997,
# ...

# %%
plt.plot(bp_imag['stim'])
